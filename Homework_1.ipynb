# %%
data = "/content/drive/MyDrive/Social Computing/database.sqlite"
print("Using DB:", data)
# Out:
# Using DB: /content/drive/MyDrive/Social Computing/database.sqlite

# %%
import sqlite3, pandas as pd

pd.set_option("display.max_colwidth", 120)
conn = sqlite3.connect(data)

# Helper to run SQL and return a DataFrame
def q(sql, params=None):
    return pd.read_sql(sql, conn, params=params or {})

# %% [markdown]
# # Exercise 1.1: Reading the dataset

# %%
tables = q("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
tables
# Out:
#               name
# 0         comments
# 1          follows
# 2            posts
# 3        reactions
# 4  sqlite_sequence
# 5            users

# %%
from typing import Dict, Any

def example_values(table: str, n: int = 3) -> Dict[str, Any]:
    df = q(f"SELECT * FROM {table} LIMIT 200")
    out = {}
    for col in df.columns:

        ex = df[col].dropna().astype(str)
        out[col] = ex.iloc[0] if len(ex) else None
    return out

rows = []
for t in tables['name']:
    if t == 'sqlite_sequence':
        continue
    schema = q(f"PRAGMA table_info({t});")
    count = q(f"SELECT COUNT(*) AS n FROM {t};")['n'][0]
    examples = example_values(t)

    # expand one row per column for a descriptive table
    for _, r in schema.iterrows():
        rows.append({
            "table": t,
            "row_count": count,
            "column": r["name"],
            "type": r["type"],
            "not_null": bool(r["notnull"]),
            "default": r["dflt_value"],
            "pk": bool(r["pk"]),
            "example_value": examples.get(r["name"])
        })

schema_df = pd.DataFrame(rows)
schema_df.sort_values(["table", "pk"], ascending=[True, False]).reset_index(drop=True)
# Out:
#         table  row_count         column          type  not_null  \
# 0    comments       5804             id       INTEGER     False
# 1    comments       5804        post_id       INTEGER      True
# 2    comments       5804        user_id       INTEGER      True
# 3    comments       5804        content          TEXT      True
# 4    comments       5804     created_at     TIMESTAMP      True
# 5     follows       7225    follower_id           INT      True
# 6     follows       7225    followed_id           INT      True
# 7       posts       1303             id       INTEGER     False
# 8       posts       1303        user_id       INTEGER      True
# 9       posts       1303        content          TEXT      True
# 10      posts       1303     created_at     TIMESTAMP      True
# 11  reactions       8276             id       INTEGER     False
# 12  reactions       8276        post_id       INTEGER      True
# 13  reactions       8276        user_id       INTEGER      True
# 14  reactions       8276  reaction_type          TEXT      True
# 15      users        210             id           INT      True
# 16      users        210       username   varchar(50)      True
# 17      users        210       location  varchar(100)     False
# 18      users        210      birthdate          date     False
# 19      users        210     created_at     timestamp     False
# 20      users        210        profile          TEXT     False
# 21      users        210       password          TEXT     False
#
#               default     pk  \
# 0                None   True
# 1                None  False
# 2                None  False
# 3                None  False
# 4   CURRENT_TIMESTAMP  False
# 5                None  False
# 6                None  False
# 7                None   True
# 8                None  False
# 9                None  False
# 10  CURRENT_TIMESTAMP  False
# 11               None   True
# 12               None  False
# 13               None  False
# 14               None  False
# 15               None  False
# 16               None  False
# 17               NULL  False
# 18               NULL  False
# 19  CURRENT_TIMESTAMP  False
# 20               None  False
# 21               None  False
#
#                                                                                                               example_value
# 0                                                                                                                         1
# 1                                                                                                                      1963
# 2                                                                                                                        55
# 3   Haha, I bet your neighbors are either loving or hating you right now! Crank it up and see if you can get a dance par...
# 4                                                                                                       2022-12-04 02:36:15
# 5                                                                                                                        12
# 6                                                                                                                         1
# 7                                                                                                                      1718
# 8                                                                                                                        10
# 9   Just had the most ridiculous encounter with a cat in Shibuya. It hissed like I was invading its turf! #CatWhisperer ...
# 10                                                                                                      2023-10-12 10:43:24
# 11                                                                                                                        1
# 12                                                                                                                     2631
# 13                                                                                                                       60
# 14                                                                                                                     like
# 15                                                                                                                        1
# 16                                                                                                             artistic_amy
# 17                                                                                                              Boston, USA
# 18                                                                                                               1997-06-30
# 19                                                                                                      2022-07-01 12:17:48
# 20  Artistic soul from Boston ? | Born in '97 | Balancing mind & style | Fashion lover | News junkie | Embracing the hig...
# 21                                                                                                                 izmQoLHw

# %% [markdown]
# # Exercise 1.2: Lurkers

# %%
lurkers_sql = """
SELECT COUNT(*) AS lurkers_count
FROM users u
WHERE u.id NOT IN (SELECT DISTINCT user_id FROM posts)
  AND u.id NOT IN (SELECT DISTINCT user_id FROM comments)
  AND u.id NOT IN (SELECT DISTINCT user_id FROM reactions);
"""
lurkers_count = q(lurkers_sql)['lurkers_count'][0]
lurkers_count
# Out:
# np.int64(55)

# %%
lurkers_list_sql = """
SELECT u.id, u.username
FROM users u
WHERE u.id NOT IN (SELECT DISTINCT user_id FROM posts)
  AND u.id NOT IN (SELECT DISTINCT user_id FROM comments)
  AND u.id NOT IN (SELECT DISTINCT user_id FROM reactions)
ORDER BY u.id;
"""
lurkers_df = q(lurkers_list_sql)
lurkers_df.head(20)
# Out:
#      id       username
# 0   474   starry_night
# 1   475    breezyday22
# 2   476   wanderlust89
# 3   477     tech_savvy
# 4   478   coffee_lover
# 5   479     bookworm77
# 6   480   traveler_guy
# 7   481   sunshine_day
# 8   482     nightowl22
# 9   483    music_lover
# 10  484     artsy_mind
# 11  485   fashion_guru
# 12  486      gamer1234
# 13  487    foodie_life
# 14  488   nature_lover
# 15  489  city_explorer
# 16  490     movie_buff
# 17  491  fitness_freak
# 18  492    photogenius
# 19  493   coding_ninja

# %% [markdown]
# # Exercise 1.3: Influencers

# %% [markdown]
# ## I think here Engagement means (comments + reactions) received on a user’s posts.

# %%
influencers_sql = """
WITH post_eng AS (
  SELECT p.user_id,
         COUNT(DISTINCT c.id) AS comment_count,
         COUNT(DISTINCT r.id) AS reaction_count,
         (COUNT(DISTINCT c.id) + COUNT(DISTINCT r.id)) AS total_engagement
  FROM posts p
  LEFT JOIN comments c ON c.post_id = p.id
  LEFT JOIN reactions r ON r.post_id = p.id
  GROUP BY p.user_id
)
SELECT u.id AS user_id, u.username, comment_count, reaction_count, total_engagement
FROM post_eng pe
JOIN users u ON u.id = pe.user_id
ORDER BY total_engagement DESC
LIMIT 5;
"""
top5_influencers = q(influencers_sql)
top5_influencers
# Out:
#    user_id      username  comment_count  reaction_count  total_engagement
# 0       54    WinterWolf            179             267               446
# 1       65   PinkPanther            152             234               386
# 2       94     PinkPetal            137             246               383
# 3       81  GoldenDreams            149             217               366
# 4       30     WildHorse            157             196               353

# %% [markdown]
# # Exercise 1.4: Spammers

# %%
spammers_detail_sql = """
WITH all_texts AS (
  SELECT user_id, content FROM posts
  UNION ALL
  SELECT user_id, content FROM comments
),
repeats AS (
  SELECT user_id, content, COUNT(*) AS times_shared
  FROM all_texts
  GROUP BY user_id, content
  HAVING COUNT(*) >= 3
)
SELECT u.id AS user_id, u.username, r.content, r.times_shared
FROM repeats r
JOIN users u ON u.id = r.user_id
ORDER BY r.times_shared DESC, u.id ASC;
"""
spammers_detail = q(spammers_detail_sql)
spammers_detail.head(20)
# Out:
#     user_id      username  \
# 0       513     night_owl
# 1       530   coding_whiz
# 2       513     night_owl
# 3       533   eco_warrior
# 4       521  history_buff
# 5       521  history_buff
# 6       521  history_buff
# 7       524     yoga_yogi
# 8       530   coding_whiz
# 9       513     night_owl
# 10      513     night_owl
# 11      521  history_buff
# 12      533   eco_warrior
# 13      513     night_owl
# 14      521  history_buff
# 15      524     yoga_yogi
# 16      530   coding_whiz
# 17      533   eco_warrior
#
#                                                                                                                     content  \
# 0                               ? Mega Giveaway Alert! ? Follow all accounts we’re following and DM us to enter! ? #Freebie
# 1                                                     Top 10 gadgets of 2025 – All available here: bestbuystuff.click/top10
# 2                         ?FLASH GIVEAWAY? Click the link in our bio to claim your PS5! Only 100 units left! #giveaway #win
# 3   Not gonna lie, I was skeptical at first. But after tagging three friends and waiting 24 hours, I actually got my fre...
# 4   A lot of you asked what helped me drop 5kg in a month—this tea really works! Here’s my referral link: fittearesults[...
# 5                                      Best way to clean your sneakers ? snag yours here ➡️ whitelabelshop.biz/sneakerclean
# 6    Mood: me refreshing for likes every 30 seconds #relatable #socialmediaproblems #algorithmwarrior #realonesknow #lmaooo
# 7   I couldn’t believe it! I just entered this giveaway and actually won a brand-new iPhone 15. Thought it was fake, but...
# 8                                          Shocking! #lol #weekend #coffee #bookstagram #design #artist #blogger #aesthetic
# 9                                  ?FREE VACATION? Tag a friend you’d take to Bali! Winners picked tonight! #TravelGiveaway
# 10                                                 Find out why everyone is switching to this new 'life hack' ? scamnow.org
# 11                              What do you think? #thoughts #motivationmonday #hustle #business #billionaire #ceo #mindset
# 12        Wearing this hoodie in my latest reel—so many DMs about it! I got it here: cosyzonedeals[.]store #OOTD #affiliate
# 13                                           This one trick will make you $500/day from home! Click here ? shadyprofits.com
# 14                                                   You need this travel pillow in your life ? shopfast.link/travelcomfort
# 15  Just entered this Xbox giveaway and the form was super simple. Took 30 seconds—let’s see if I get lucky! xboxdrop24[...
# 16                                 ?FREE VACATION? Tag a friend you’d take to Bali! Winners picked tonight! #TravelGiveaway
# 17                                 Revolutionary idea! #fashionblogger #instafashion #model #runway #hairstyle #ootd #trend
#
#     times_shared
# 0              8
# 1              8
# 2              7
# 3              7
# 4              5
# 5              5
# 6              5
# 7              5
# 8              5
# 9              4
# 10             4
# 11             4
# 12             4
# 13             3
# 14             3
# 15             3
# 16             3
# 17             3

# %%
spammers_summary_sql = """
WITH all_texts AS (
  SELECT user_id, content FROM posts
  UNION ALL
  SELECT user_id, content FROM comments
),
repeats AS (
  SELECT user_id, content, COUNT(*) AS times_shared
  FROM all_texts
  GROUP BY user_id, content
  HAVING COUNT(*) >= 3
)
SELECT u.id AS user_id, u.username,
       COUNT(*) AS distinct_repeated_texts,
       SUM(times_shared) AS total_repeated_instances
FROM repeats r
JOIN users u ON u.id = r.user_id
GROUP BY u.id, u.username
ORDER BY total_repeated_instances DESC, distinct_repeated_texts DESC;
"""
spammers_summary = q(spammers_summary_sql)
spammers_summary
# Out:
#    user_id      username  distinct_repeated_texts  total_repeated_instances
# 0      513     night_owl                        5                        26
# 1      521  history_buff                        5                        22
# 2      530   coding_whiz                        3                        16
# 3      533   eco_warrior                        3                        14
# 4      524     yoga_yogi                        2                         8
